# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-d1aca559-8faa-44ae-a2b3-6beb09db5266" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1aca559-8faa-44ae-a2b3-6beb09db5266">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("employee_attrition_hr_2026.csv")
df.head(10)
# Out:
#    employee_id  age  gender marital_status education_level        department  \
# 0         1001   37    Male       Divorced         Masters       Engineering
# 1         1002   24  Female        Married       Bachelors           Finance
# 2         1003   24  Female         Single       Bachelors         Marketing
# 3         1004   44    Male         Single       Bachelors             Sales
# 4         1005   37  Female       Divorced       Bachelors             Sales
# 5         1006   25    Male        Married       Bachelors  Customer Support
# 6         1007   47  Female       Divorced             PhD  Customer Support
# 7         1008   63    Male         Single       Bachelors       Engineering
# 8         1009   35  Female         Single       Bachelors           Finance
# 9         1010   33  Female         Single       Bachelors             Sales
#
#                 job_role  job_level  monthly_income  stock_option_level  ...  \
# ...

# %%
df.describe()
# Out:
#        employee_id          age    job_level  monthly_income  \
# count  5000.000000  5000.000000  5000.000000      5000.00000
# mean   3500.500000    37.119800     2.925200      6990.71980
# std    1443.520003     8.234161     1.201621      2701.89936
# min    1001.000000    21.000000     1.000000      1500.00000
# 25%    2250.750000    31.000000     2.000000      4971.00000
# 50%    3500.500000    37.000000     3.000000      6569.00000
# 75%    4750.250000    43.000000     4.000000      8604.25000
# max    6000.000000    64.000000     5.000000     21609.00000
#
#        stock_option_level  salary_hike_pct  years_at_company  \
# count         5000.000000      5000.000000       5000.000000
# mean             1.089800        11.518200          6.724620
# std              0.936542         3.408021          3.500219
# min              0.000000         0.000000          0.000000
# 25%              0.000000         9.300000          4.275000
# ...

# %%
df.shape
# Out:
# (5000, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   employee_id                    5000 non-null   int64
#  1   age                            5000 non-null   int64
#  2   gender                         5000 non-null   object
#  3   marital_status                 5000 non-null   object
#  4   education_level                5000 non-null   object
#  5   department                     5000 non-null   object
#  6   job_role                       5000 non-null   object
#  7   job_level                      5000 non-null   int64
#  8   monthly_income                 5000 non-null   int64
#  9   stock_option_level             5000 non-null   int64
#  10  salary_hike_pct                5000 non-null   float64
#  11  years_at_company               5000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# employee_id                        0
# age                                0
# gender                             0
# marital_status                     0
# education_level                    0
# department                         0
# job_role                           0
# job_level                          0
# monthly_income                     0
# stock_option_level                 0
# salary_hike_pct                    0
# years_at_company                   0
# total_working_years                0
# years_since_promotion              0
# num_prior_companies                0
# work_mode                          0
# commute_minutes                    0
# overtime_hours_per_week            0
# business_travel_days_per_year      0
# training_hours                     0
# manager_support_score              0
# burnout_score                      0
# engagement_score                   0
# work_life_balance_score            0
# performance_rating                 0
# ...

# %%
print(df.describe())
# Out:
# Summary Statistics
#        employee_id          age    job_level  monthly_income  \
# count  5000.000000  5000.000000  5000.000000      5000.00000
# mean   3500.500000    37.119800     2.925200      6990.71980
# std    1443.520003     8.234161     1.201621      2701.89936
# min    1001.000000    21.000000     1.000000      1500.00000
# 25%    2250.750000    31.000000     2.000000      4971.00000
# 50%    3500.500000    37.000000     3.000000      6569.00000
# 75%    4750.250000    43.000000     4.000000      8604.25000
# max    6000.000000    64.000000     5.000000     21609.00000
#
#        stock_option_level  salary_hike_pct  years_at_company  \
# count         5000.000000      5000.000000       5000.000000
# mean             1.089800        11.518200          6.724620
# std              0.936542         3.408021          3.500219
# min              0.000000         0.000000          0.000000
# 25%              0.000000         9.300000          4.275000
# ...

# %%
df["attrition"].value_counts()
# Out:
# attrition
# No     4105
# Yes     895
# Name: count, dtype: int64

# %%
attrition_rate = (
    df["attrition"].value_counts(normalize=True)*100
)
attrition_rate
# Out:
# attrition
# No     82.1
# Yes    17.9
# Name: proportion, dtype: float64

# %%
dept_attrition = pd.crosstab(
    df["department"],
    df["attrition"])
dept_attrition
# Out:
# attrition                 No  Yes
# department
# Customer Support         483  153
# Engineering             1142  194
# Finance                  357   79
# Human Resources          200   44
# Marketing                357   83
# Operations               549  114
# Research & Development   349   61
# Sales                    668  167

# %%
salary = df.groupby("department")["monthly_income"].mean()
salary
# Out:
# department
# Customer Support          5527.191824
# Engineering               8123.717066
# Finance                   6961.412844
# Human Resources           6045.725410
# Marketing                 6625.229545
# Operations                6615.265460
# Research & Development    7480.809756
# Sales                     6834.170060
# Name: monthly_income, dtype: float64

# %%
burnout = df.groupby("attrition")["burnout_score"].mean()
burnout
# Out:
# attrition
# No     3.809574
# Yes    5.059777
# Name: burnout_score, dtype: float64

# %%
manager = df.groupby("attrition")["manager_support_score"].mean()
manager
# Out:
# attrition
# No     6.814982
# Yes    5.689385
# Name: manager_support_score, dtype: float64

# %%
overtime = df.groupby("attrition")["overtime_hours_per_week"].mean()
overtime
# Out:
# attrition
# No     6.404409
# Yes    8.772067
# Name: overtime_hours_per_week, dtype: float64

# %%
df.nlargest(10,"monthly_income")
# Out:
#       employee_id  age      gender marital_status education_level  \
# 3197         4198   49      Female         Single         Masters
# 4824         5825   49      Female        Married             PhD
# 2733         3734   56        Male         Single             PhD
# 2906         3907   51      Female        Married         Masters
# 2856         3857   41      Female        Married         Masters
# 543          1544   44  Non-binary        Married             PhD
# 4786         5787   46        Male        Married         Masters
# 1955         2956   41      Female         Single         Masters
# 4955         5956   46      Female        Married       Bachelors
# 2270         3271   44  Non-binary         Single             PhD
#
#        department             job_role  job_level  monthly_income  \
# 3197  Engineering  Engineering Manager          5           21609
# 4824  Engineering  Engineering Manager          5           21073
# ...

# %%
employee= df.select_dtypes(include="number")
print(employee.corr())
# Out:
#                                employee_id       age  job_level  \
# employee_id                       1.000000  0.005412   0.013325
# age                               0.005412  1.000000   0.644008
# job_level                         0.013325  0.644008   1.000000
# monthly_income                    0.013304  0.537682   0.772071
# stock_option_level                0.029711  0.259302   0.399342
# salary_hike_pct                  -0.017513 -0.047761  -0.047314
# years_at_company                  0.027675  0.578137   0.710961
# total_working_years               0.018762  0.698456   0.629893
# years_since_promotion            -0.004953  0.152282   0.150193
# num_prior_companies              -0.009743  0.031281   0.012760
# commute_minutes                  -0.003238  0.003029   0.009747
# overtime_hours_per_week           0.017523  0.005188   0.022345
# business_travel_days_per_year    -0.010942  0.020569   0.027779
# training_hours                    0.018826 -0.075395  -0.115819
# ...

# %%
df["attrition"].value_counts().plot(kind="bar")
plt.title("Employee Attrition")
plt.xlabel("Attrition")
plt.ylabel("Count")
plt.show()

# %%
df["department"].value_counts().plot(kind="bar")
plt.title("Employees by Department")
plt.show()

# %%
plt.hist(df["monthly_income"], bins=20)
plt.title("Monthly Income Distribution")
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(df["burnout_score"], bins=15)
plt.title("Burnout Score")
plt.show()

# %%
df.to_csv("clean_employee_attrition_hr.csv", index=False)
